# %% [markdown]
# # Notebook for data processing and simple visualization

# %%
from scraper import KinoPoisk
import pandas as pd
import numpy as np
from currency_converter import CurrencyConverter
import sqlite3
from datetime import date
import sys
from IPython.display import clear_output
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as tick
import plotly.express as px

# %% [markdown]
# ## Raw Data

# %%
df = pd.read_csv('KinoPoisk.csv')
df.head(5)
# Out:
#                                        Аудиодорожки Субтитры  Качество видео  \
# 0                               Русский, Английский  Русские             NaN
# 1                               Русский, Английский  Русские             NaN
# 2                                               NaN      NaN             NaN
# 3  Русский, Русский 5.1, Английский, Английский 5.1  Русские             NaN
# 4                                               NaN      NaN             NaN
#
#    Год производства               Страна  \
# 0              1999                  США
# 1              1993                  США
# 2              1994                  США
# 3              1994                  США
# 4              2003  Новая Зеландия, США
#
#                                           Жанр  \
# 0                     драма, фэнтези, криминал
# 1           драма, биография, история, военный
# 2                                        драма
# 3  драма, комедия, мелодрама, история, военный
# ...

# %% [markdown]
# ## Part 1: Data proccessing

# %% [markdown]
# ### Deleting too small columns

# %%
df_cleared = df.dropna(axis=1, thresh=189)
df_cleared.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Аудиодорожки      209 non-null    object
#  1   Субтитры          209 non-null    object
#  2   Год производства  250 non-null    int64
#  3   Страна            250 non-null    object
#  4   Жанр              250 non-null    object
#  5   Слоган            250 non-null    object
#  6   Режиссер          250 non-null    object
#  7   Сценарий          250 non-null    object
#  8   Продюсер          204 non-null    object
#  9   Оператор          215 non-null    object
#  10  Композитор        250 non-null    object
#  11  Художник          248 non-null    object
#  12  Монтаж            247 non-null    object
#  13  Бюджет            197 non-null    object
#  14  Сборы в США       189 non-null    object
#  15  Сборы в мире      196 non-null    object
# ...

# %% [markdown]
# ### Transforming data

# %%
def budget_transformation_to_usd(x):
    c = CurrencyConverter()
    currencies_signs = ['€', 'DEM', 'р.', '₽', '£', 'FRF', '¥', 'DKK']
    currencies = ['EUR', 'DEM', 'RUB', 'RUB', 'GBP', 'FRF', 'JPY', 'DKK']
    try:
        year = df_cleared.loc[df_cleared['Бюджет'] == x, 'Год производства'].values[0]
        for currency in currencies_signs:
            if type(x) == str:
                if currency in x:
                    x = float(x.replace(currency, ''))
                    x = (c.convert(x, currencies[currencies_signs.index(currency)], 'USD', date=date(year, 1, 1)))
                else:
                    continue
            elif type(x) != str:
                x = str(x)
                if currency in x:
                    x = float(x.replace(currency, ''))
                    x = (c.convert(x, currencies[currencies_signs.index(currency)], 'USD', date=date(year, 1, 1)))
                else:
                    continue
        return x
    except:
        return x

def budget_transformation():
    df_cleared['Бюджет'] = df_cleared['Бюджет'].str.replace(' ', '')
    df_cleared['Бюджет'] = df_cleared['Бюджет'].str.replace('$', '')
    df_cleared['Бюджет'] = df_cleared['Бюджет'].apply(lambda y: budget_transformation_to_usd(x=y))
    df_cleared['Бюджет'] = df_cleared['Бюджет'].apply(pd.to_numeric)

budget_transformation()
# Out:
# /tmp/ipykernel_12906/89148013.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleared['Бюджет'] = df_cleared['Бюджет'].str.replace(' ', '')
# /tmp/ipykernel_12906/89148013.py:27: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleared['Бюджет'] = df_cleared['Бюджет'].str.replace('$', '')
# /tmp/ipykernel_12906/89148013.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_cleared['Бюджет']
# Out:
# 0       60000000.0
# 1       22000000.0
# 2       25000000.0
# 3       55000000.0
# 4       94000000.0
#           ...
# 245     30000000.0
# 246            NaN
# 247    100000000.0
# 248     12000000.0
# 249            NaN
# Name: Бюджет, Length: 250, dtype: float64

# %%
df_cleared.columns
# Out:
# Index(['Аудиодорожки', 'Субтитры', 'Год производства', 'Страна', 'Жанр',
#        'Слоган', 'Режиссер', 'Сценарий', 'Продюсер', 'Оператор', 'Композитор',
#        'Художник', 'Монтаж', 'Бюджет', 'Сборы в США', 'Сборы в мире',
#        'Зрители', 'Премьера в мире', 'Релиз на DVD', 'Возраст', 'Рейтинг MPAA',
#        'Время', 'Название фильма', 'Актеры', 'Оценка фильма'],
#       dtype='object')

# %%
def fees_usa_transformation():
    df_cleared['Сборы в США'] = df_cleared['Сборы в США'].str.replace(' ', '')
    df_cleared['Сборы в США'] = df_cleared['Сборы в США'].str.replace('$', '')
    df_cleared['Сборы в США'] = df_cleared['Сборы в США'].str.replace('nan', '0')
    df_cleared['Сборы в США'] = df_cleared['Сборы в США'].apply(pd.to_numeric)
fees_usa_transformation()
# Out:
# /tmp/ipykernel_12906/3988036051.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleared['Сборы в США'] = df_cleared['Сборы в США'].str.replace(' ', '')
# /tmp/ipykernel_12906/3988036051.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleared['Сборы в США'] = df_cleared['Сборы в США'].str.replace('$', '')
# /tmp/ipykernel_12906/3988036051.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
def fees_world_transformation():
    df_cleared['Сборы в мире'] = df_cleared['Сборы в мире'].str.replace(' ', '')
    df_cleared['Сборы в мире'] = df_cleared['Сборы в мире'].str.replace('$', '')
    df_cleared['Сборы в мире'] = df_cleared['Сборы в мире'].str.replace('+', '')
    df_cleared['Сборы в мире'] = df_cleared['Сборы в мире'].apply(lambda x: max(x.split('=')) if type(x) == str else x)
    df_cleared['Сборы в мире'] = df_cleared['Сборы в мире'].str.replace('nan', '0')
    df_cleared['Сборы в мире'] = df_cleared['Сборы в мире'].apply(pd.to_numeric)
fees_world_transformation()
# Out:
# /tmp/ipykernel_12906/235227528.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleared['Сборы в мире'] = df_cleared['Сборы в мире'].str.replace(' ', '')
# /tmp/ipykernel_12906/235227528.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_cleared['Сборы в мире'] = df_cleared['Сборы в мире'].str.replace('$', '')
# /tmp/ipykernel_12906/235227528.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
def views(x):
    list_of_symbols = [' ', 'млн.', 'тыс.', 'млн', 'тыс', 'nan']
    list_of_replacements = ['', '000000', '000', '000000', '000', '0']
    if type(x) != str:
        x = str(x)
    for symbol in list_of_symbols:
        if symbol in x:
            x = x.replace(symbol, list_of_replacements[list_of_symbols.index(symbol)])
    if '.' in x:
        x = x.replace('.', '')
        x = float(x) * (0.1)
        return int(x)
    else:
        return int(x)
df_cleared['Зрители'] = df_cleared['Зрители'].apply(views)
clear_output()

# %%
pd.options.display.float_format = "{:.2f}".format
df_cleared.describe()
# Out:
#        Год производства        Бюджет  Сборы в США  Сборы в мире      Зрители  \
# count            250.00        197.00       189.00        196.00       250.00
# mean            1997.19   90395375.34 156109426.86  361803869.74  24004241.60
# std               16.41  189301775.45 151526602.79  429456474.30  25235395.28
# min             1939.00      25313.00      5710.00       1887.00         0.00
# 25%             1987.25   18500000.00  44619100.00   57465933.00   1400000.00
# 50%             2001.00   50000000.00 118450002.00  264019190.50  15950000.00
# 75%             2010.00  113000000.00 223808164.00  518040497.25  40525000.00
# max             2021.00 2400000000.00 858373000.00 2923905528.00 135400000.00
#
#        Оценка фильма
# count         250.00
# mean            8.22
# std             0.25
# min             7.70
# 25%             8.00
# 50%             8.20
# 75%             8.40
# max             9.10

# %%
def categorical_data_processing(column):
    all_categories = []
    for record in df_cleared[column]:
        new_record = record.split(',')
        for word in new_record:
            word = word.strip()
        all_categories.append(word)
    all_categories = list(set(all_categories))
    for category in all_categories:
        df_cleared[column + ': ' + category] = df_cleared[column].apply(lambda x: True if category in x else False)

categorical_data_processing(column='Жанр')
categorical_data_processing(column='Страна')
categorical_data_processing(column='Актеры')
categorical_data_processing(column='Режиссер')
categorical_data_processing(column='Сценарий')
clear_output()

# %%
df_cleared.columns
# Out:
# Index(['Аудиодорожки', 'Субтитры', 'Год производства', 'Страна', 'Жанр',
#        'Слоган', 'Режиссер', 'Сценарий', 'Продюсер', 'Оператор',
#        ...
#        'Сценарий: Владимир Богомолов', 'Сценарий: Хаяо Миядзаки',
#        'Сценарий: Элем Климов', 'Сценарий: Алексей Балабанов',
#        'Сценарий: Джон Гроган', 'Сценарий: Евгений Шварц',
#        'Сценарий: Флориан Хенкель фон Доннерсмарк', 'Сценарий: Роджер Эвери',
#        'Сценарий: Марио Пьюзо', 'Сценарий: Томас Ян'],
#       dtype='object', length=635)

# %%
'''conn = sqlite3.connect('KinoPoisk.db')
c = conn.cursor()
for row in c.execute('SELECT * FROM films_data'):
    print(row)
conn.commit()
conn.close()'''
# Out:
# "conn = sqlite3.connect('KinoPoisk.db')\nc = conn.cursor()\nfor row in c.execute('SELECT * FROM films_data'):\n    print(row)\nconn.commit()\nconn.close()"

# %% [markdown]
# ## Part 2: Visualization

# %%
def reformat_large_tick_values(tick_val, pos):
    """
    Turns large tick values (in the billions, millions and thousands) such as 4500 into 4.5K and also appropriately turns 4000 into 4K (no zero after the decimal).
    """
    if tick_val >= 1000000000:
        val = round(tick_val/1000000000, 1)
        new_tick_format = '{:}B'.format(val)
    elif tick_val >= 1000000:
        val = round(tick_val/1000000, 1)
        new_tick_format = '{:}M'.format(val)
    elif tick_val >= 1000:
        val = round(tick_val/1000, 1)
        new_tick_format = '{:}K'.format(val)
    elif tick_val < 1000:
        new_tick_format = round(tick_val, 1)
    else:
        new_tick_format = tick_val

    # make new_tick_format into a string value
    new_tick_format = str(new_tick_format)
    
    # code below will keep 4.5M as is but change values such as 4.0M to 4M since that zero after the decimal isn't needed
    index_of_decimal = new_tick_format.find(".")
    
    if index_of_decimal != -1:
        value_after_decimal = new_tick_format[index_of_decimal+1]
        if value_after_decimal == "0":
            # remove the 0 after the decimal point since it's not needed
            new_tick_format = new_tick_format[0:index_of_decimal] + new_tick_format[index_of_decimal+2:]
            
    return new_tick_format

# %% [markdown]
# ### General analysis

# %% [markdown]
# #### Histograms

# %%
df_cleared['Зрители'].hist()
plt.title('Distribution of viewers')
ax = plt.gca()
ax.xaxis.set_major_formatter(tick.FuncFormatter(reformat_large_tick_values))
plt.show()
df_cleared['Сборы в мире'].hist()
plt.title('Distribution of total movie fees')
ax = plt.gca()
ax.xaxis.set_major_formatter(tick.FuncFormatter(reformat_large_tick_values))
plt.show()
df_cleared['Сборы в США'].hist()
plt.title('Distribution of movie fees in USA')
ax = plt.gca()
ax.xaxis.set_major_formatter(tick.FuncFormatter(reformat_large_tick_values))
plt.show()
df_cleared['Бюджет'].hist()
plt.title('Distribution of films budget')
ax = plt.gca()
ax.xaxis.set_major_formatter(tick.FuncFormatter(reformat_large_tick_values))
plt.show()

# %% [markdown]
# #### Time-series plots

# %%
viewers_per_year = df_cleared.groupby('Год производства')['Зрители'].mean()
sns.lineplot(viewers_per_year)
ax = plt.gca()
ax.yaxis.set_major_formatter(tick.FuncFormatter(reformat_large_tick_values))
plt.title('Viewers per year')
plt.show()

total_fees_per_year = df_cleared.groupby('Год производства')['Сборы в мире'].mean()
sns.lineplot(total_fees_per_year)
ax = plt.gca()
ax.yaxis.set_major_formatter(tick.FuncFormatter(reformat_large_tick_values))
plt.title('Total movies fees per year')
plt.show()

# %% [markdown]
# ### Categorical analysis

# %%
def bar_plot(name_of_category_column, name_of_measerment_column, title_name, aggregation_func='mean', scale_of_axis = None):
    cols = name_of_category_column+': '
    if aggregation_func == 'mean':
        dictionary = {col.split(': ')[1]: df_cleared[df_cleared[col]==True][name_of_measerment_column].mean() for col in df_cleared.columns if cols in col}
    elif aggregation_func == 'median':
        dictionary = {col.split(': ')[1]: df_cleared[df_cleared[col]==True][name_of_measerment_column].median() for col in df_cleared.columns if cols in col}
    for element in dictionary.copy():
        if 'nan' in str(dictionary[element]):
            del dictionary[element]
    dictionary = dict(sorted(dictionary.items(), key=lambda x:x[1], reverse=True))
    categories = list(dictionary.keys())
    vals = [float(dictionary[category]) for category in categories]
    sns.barplot(x=vals, y=categories)
    plt.title(title_name)
    ax = plt.gca()
    ax.xaxis.set_major_formatter(tick.FuncFormatter(reformat_large_tick_values))
    if scale_of_axis != None:
        plt.xlim(scale_of_axis)
    plt.show()

# %%
def count_plot(name_of_category_column, title_name):
    cols = name_of_category_column+': '
    dictionary = {col.split(': ')[1]: df_cleared[df_cleared[col]==True]['Название фильма'].count() for col in df_cleared.columns if cols in col}
    dictionary = dict(sorted(dictionary.items(), key=lambda x:x[1], reverse=True))
    categories = list(dictionary.keys())
    amounts = [float(dictionary[category]) for category in categories]
    sns.barplot(x=amounts, y=categories, color='green')
    plt.title(title_name)
    plt.show()

# %% [markdown]
# #### Genre

# %%
cols = 'Жанр'+': '
dictionary = {col.split(': ')[1]: df_cleared[df_cleared[col]==True]['Название фильма'].count() for col in df_cleared.columns if cols in col}
dictionary = dict(sorted(dictionary.items(), key=lambda x:x[1], reverse=True))
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))
categories = list(dictionary.keys())
amounts = [float(dictionary[category]) for category in categories]
plt.pie(x=dictionary.values(), labels=categories)
plt.show()

# %%
count_plot(name_of_category_column='Жанр', title_name='Количество фильмов каждого жанра')
bar_plot(name_of_category_column='Жанр', name_of_measerment_column='Сборы в мире',title_name='Средние сборы фильма по жанрам в долларах')
bar_plot(name_of_category_column='Жанр', name_of_measerment_column='Сборы в США', title_name='Средние сборы фильма в США по жанрам в долларах')
bar_plot(name_of_category_column='Жанр', name_of_measerment_column='Зрители', title_name='Среднее кол-во зрителей фильма по жанрам')
bar_plot(name_of_category_column='Жанр', name_of_measerment_column='Оценка фильма', title_name='Средняя оценка фильма по жанрам', scale_of_axis=(8,8.6))

# %% [markdown]
# #### Country

# %%
count_plot(name_of_category_column='Страна', title_name='Кол-во фильмов по странам производства')
bar_plot(name_of_category_column='Страна', name_of_measerment_column='Сборы в мире', title_name='Средние сборы фильма в мире по странам производства')
bar_plot(name_of_category_column='Страна', name_of_measerment_column='Сборы в США', title_name='Средние сборы фильма в США по странам производства')
bar_plot(name_of_category_column='Страна', name_of_measerment_column='Зрители', title_name='Среднее кол-во зрителей по странам производства')
bar_plot(name_of_category_column='Страна', name_of_measerment_column='Оценка фильма', title_name='Средняя оценка фильмов по странам производства', scale_of_axis=(7,9))

# %% [markdown]
# #### Producer

# %% [markdown]
# #### Screenwriter

# %% [markdown]
# #### Actors
